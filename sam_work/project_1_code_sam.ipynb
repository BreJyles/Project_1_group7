# %%
#importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import seaborn as sns

# %%
project_colors = ["#FF8360","#E8E288","#7DCE82","#3CDBD3","#00FFF5"]
sns.set_palette(project_colors)

# %%
#loading the data
online_shopping_path = "../starter_code/online_shopping.csv"

# %%
#importing the .csv
shopping_data = pd.read_csv(online_shopping_path)

# %%
#previewing the data
shopping_data.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA  ...
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
#
#    Avg_Price  Delivery_Charges  Coupon_Status  GST      Date Offline_Spend  \
# 0     153.71               6.5           Used  0.1  1/1/2019        4500.0
# 1     153.71               6.5           Used  0.1  1/1/2019        4500.0
# 2     122.77               6.5       Not Used  0.1  1/1/2019        4500.0
# 3      81.50               6.5        Clicked  0.1  1/1/2019        4500.0
# 4     153.71               6.5        Clicked  0.1  1/1/2019        4500.0
#
#    Online_Spend  Month  Coupon_Code Discount_pct
# 0        2424.5      1       ELEC10         10.0
# 1        2424.5      1       ELEC10         10.0
# 2        2424.5      1       ELEC10         10.0
# 3        2424.5      1       ELEC10         10.0
# 4        2424.5      1       ELEC10         10.0
#
# [5 rows x 21 columns]

# %%
shopping_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
#  15  Date                 52924 non-null  object
#  16  Offline_Spend        52924 non-null  float64
#  17  Online_Spend         52924 non-null  float64
#  18  Month                52955 non-null  int64
#  19  Coupon_Code          52555 non-null  object
#  20  Discount_pct         52555 non-null  float64
# dtypes: float64(10), int64(2), object(9)
# memory usage: 8.5+ MB

# %%
print(shopping_data.columns)
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
clean_shopping_df = shopping_data.drop(['Unnamed: 0', 'Product_SKU'],  axis=1, inplace=False)
clean_shopping_df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       2019-01-01
# 1     17850.0      M  Chicago           12.0         16680.0       2019-01-01
# 2     17850.0      M  Chicago           12.0         16696.0       2019-01-01
# 3     17850.0      M  Chicago           12.0         16699.0       2019-01-01
# 4     17850.0      M  Chicago           12.0         16700.0       2019-01-01
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST      Date  \
# 0       1.0     153.71               6.5          Used  0.1  1/1/2019
# 1       1.0     153.71               6.5          Used  0.1  1/1/2019
# 2       2.0     122.77               6.5      Not Used  0.1  1/1/2019
# 3       1.0      81.50               6.5       Clicked  0.1  1/1/2019
# 4       1.0     153.71               6.5       Clicked  0.1  1/1/2019
#
#    Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0         4500.0        2424.5      1      ELEC10          10.0
# 1         4500.0        2424.5      1      ELEC10          10.0
# 2         4500.0        2424.5      1      ELEC10          10.0
# 3         4500.0        2424.5      1      ELEC10          10.0
# 4         4500.0        2424.5      1      ELEC10          10.0

# %%
clean_shopping_df = clean_shopping_df.dropna(axis=0, how="any")
clean_shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52524 entries, 0 to 52923
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  object
#  6   Product_Description  52524 non-null  object
#  7   Product_Category     52524 non-null  object
#  8   Quantity             52524 non-null  float64
#  9   Avg_Price            52524 non-null  float64
#  10  Delivery_Charges     52524 non-null  float64
#  11  Coupon_Status        52524 non-null  object
#  12  GST                  52524 non-null  float64
#  13  Date                 52524 non-null  object
#  14  Offline_Spend        52524 non-null  float64
#  15  Online_Spend         52524 non-null  float64
#  16  Month                52524 non-null  int64
#  17  Coupon_Code          52524 non-null  object
#  18  Discount_pct         52524 non-null  float64
# dtypes: float64(10), int64(1), object(8)
# memory usage: 8.0+ MB

# %%
clean_shopping_df.Product_Category.value_counts()
# Out:
# Product_Category
# Apparel                 18126
# Nest-USA                14013
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Nest                     2198
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Nest-Canada               317
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64

# %%
clean_shopping_df.Coupon_Status.value_counts()
# Out:
# Coupon_Status
# Clicked     26720
# Used        17778
# Not Used     8026
# Name: count, dtype: int64

# %%
clean_shopping_df.Coupon_Code.value_counts()
# Out:
# Coupon_Code
# SALE20     6373
# SALE30     5915
# SALE10     5838
# ELEC10     4826
# ELEC30     4647
# ELEC20     4540
# EXTRA10    2317
# OFF10      2250
# EXTRA20    2211
# OFF20      2202
# OFF30      2061
# EXTRA30    2047
# NE30       1003
# NE20        740
# AIO10       654
# AIO20       618
# AIO30       610
# NE10        455
# NJ20        299
# NJ10        280
# HGEAR10     267
# HGEAR20     267
# HGEAR30     237
# WEMP20      205
# WEMP30      185
# NJ30        170
# WEMP10      164
# NCA10       116
# NCA30       110
# BT10         98
# ACC20        97
# NCA20        91
# GC10         89
# BT30         87
# BT20         83
# ACC30        77
# ACC10        60
# HOU20        50
# HOU10        42
# GC20         41
# HOU30        30
# GC30         29
# AND30        16
# AND10        14
# AND20        13
# Name: count, dtype: int64

# %%
clean_shopping_df.Gender.value_counts()
# Out:
# Gender
# F    32767
# M    19757
# Name: count, dtype: int64

# %%
clean_shopping_df.Location.value_counts()
# Out:
# Location
# Chicago          18240
# California       16008
# New York         11097
# New Jersey        4470
# Washington DC     2709
# Name: count, dtype: int64

# %%
# convert date
# clean_shopping_df = pd.to_datetime(clean_shopping_df["Transaction_Date"])
# clean_shopping_df.head()
clean_shopping_df["Transaction_Date"] = pd.to_datetime(clean_shopping_df["Transaction_Date"])

# %%
clean_shopping_df.tail()
# Out:
#        CustomerID Gender    Location  Tenure_Months  Transaction_ID  \
# 52919     13155.0      F  California            8.0         22504.0
# 52920     18077.0      M     Chicago           34.0         24250.0
# 52921     16085.0      M  California           15.0         39991.0
# 52922     16085.0      M  California           15.0         39991.0
# 52923     13659.0      F     Chicago            8.0         39998.0
#
#       Transaction_Date                Product_Description  \
# 52919       2019-03-10                Gift Card - $250.00
# 52920       2019-03-28                 Gift Card - $25.00
# 52921       2019-10-06  Google Leather Perforated Journal
# 52922       2019-10-06      Google Spiral Leather Journal
# 52923       2019-10-06     Google Spiral Journal with Pen
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 52919            Gift Cards       1.0     250.00               0.0
# 52920            Gift Cards       1.0      25.00               0.0
# 52921  Notebooks & Journals       1.0      10.80               6.0
# 52922  Notebooks & Journals       1.0       9.60               6.0
# 52923  Notebooks & Journals       1.0       5.59               6.5
#
#       Coupon_Status   GST       Date  Offline_Spend  Online_Spend  Month  \
# 52919       Clicked  0.05  3/10/2019         2500.0       1294.22      3
# 52920          Used  0.05  3/28/2019         2000.0       1066.12      3
# 52921       Clicked  0.05  10/6/2019         3000.0       2230.76     10
# 52922          Used  0.05  10/6/2019         3000.0       2230.76     10
# 52923      Not Used  0.05  10/6/2019         3000.0       2230.76     10
#
#       Coupon_Code  Discount_pct
# 52919        GC30          30.0
# 52920        GC30          30.0
# 52921        NJ10          10.0
# 52922        NJ10          10.0
# 52923        NJ10          10.0

# %%
clean_shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52524 entries, 0 to 52923
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  datetime64[ns]
#  6   Product_Description  52524 non-null  object
#  7   Product_Category     52524 non-null  object
#  8   Quantity             52524 non-null  float64
#  9   Avg_Price            52524 non-null  float64
#  10  Delivery_Charges     52524 non-null  float64
#  11  Coupon_Status        52524 non-null  object
#  12  GST                  52524 non-null  float64
#  13  Date                 52524 non-null  object
#  14  Offline_Spend        52524 non-null  float64
#  15  Online_Spend         52524 non-null  float64
#  16  Month                52524 non-null  int64
#  17  Coupon_Code          52524 non-null  object
#  18  Discount_pct         52524 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(7)
# memory usage: 8.0+ MB

# %%
clean_shopping_df["Transaction_Date"] = clean_shopping_df["Transaction_Date"].dt.strftime("%m-%d-%Y")

clean_shopping_df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       01-01-2019
# 1     17850.0      M  Chicago           12.0         16680.0       01-01-2019
# 2     17850.0      M  Chicago           12.0         16696.0       01-01-2019
# 3     17850.0      M  Chicago           12.0         16699.0       01-01-2019
# 4     17850.0      M  Chicago           12.0         16700.0       01-01-2019
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST      Date  \
# 0       1.0     153.71               6.5          Used  0.1  1/1/2019
# 1       1.0     153.71               6.5          Used  0.1  1/1/2019
# 2       2.0     122.77               6.5      Not Used  0.1  1/1/2019
# 3       1.0      81.50               6.5       Clicked  0.1  1/1/2019
# 4       1.0     153.71               6.5       Clicked  0.1  1/1/2019
#
#    Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0         4500.0        2424.5      1      ELEC10          10.0
# 1         4500.0        2424.5      1      ELEC10          10.0
# 2         4500.0        2424.5      1      ELEC10          10.0
# 3         4500.0        2424.5      1      ELEC10          10.0
# 4         4500.0        2424.5      1      ELEC10          10.0

# %%
clean_shopping_df["Transaction_Date"] = pd.to_datetime(clean_shopping_df["Transaction_Date"])

# %%
clean_shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52524 entries, 0 to 52923
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  datetime64[ns]
#  6   Product_Description  52524 non-null  object
#  7   Product_Category     52524 non-null  object
#  8   Quantity             52524 non-null  float64
#  9   Avg_Price            52524 non-null  float64
#  10  Delivery_Charges     52524 non-null  float64
#  11  Coupon_Status        52524 non-null  object
#  12  GST                  52524 non-null  float64
#  13  Date                 52524 non-null  object
#  14  Offline_Spend        52524 non-null  float64
#  15  Online_Spend         52524 non-null  float64
#  16  Month                52524 non-null  int64
#  17  Coupon_Code          52524 non-null  object
#  18  Discount_pct         52524 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(7)
# memory usage: 8.0+ MB

# %%
clean_shopping_df["Location"] = clean_shopping_df.Location.replace({"New York": "New Jersey"})
clean_shopping_df.Location.value_counts().head
# Out:
# <bound method NDFrame.head of Location
# Chicago          18240
# California       16008
# New Jersey       15567
# Washington DC     2709
# Name: count, dtype: int64>

# %%
clean_shopping_df["Location"] = clean_shopping_df.Location.replace({"New Jersey": "Washington DC"})
clean_shopping_df.Location.value_counts().head
# Out:
# <bound method NDFrame.head of Location
# Washington DC    18276
# Chicago          18240
# California       16008
# Name: count, dtype: int64>

# %%
clean_shopping_df["Location"] = clean_shopping_df.Location.replace({"Washington DC": "North East"})
clean_shopping_df.Location.value_counts().head
# Out:
# <bound method NDFrame.head of Location
# North East    18276
# Chicago       18240
# California    16008
# Name: count, dtype: int64>

# %%
clean_shopping_df["Product_Category"] = clean_shopping_df.Product_Category.replace({"Nest-Canada": "Nest-USA"})
clean_shopping_df.Product_Category.value_counts().head
# Out:
# <bound method NDFrame.head of Product_Category
# Apparel                 18126
# Nest-USA                14330
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Nest                     2198
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64>

# %%
clean_shopping_df["Product_Category"] = clean_shopping_df.Product_Category.replace({"Nest-USA": "Nest"})
clean_shopping_df.Product_Category.value_counts().head
# Out:
# <bound method NDFrame.head of Product_Category
# Apparel                 18126
# Nest                    16528
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64>

# %%
# Build scatter plot for item cost vs shipping cost
x = clean_shopping_df["Avg_Price"]
y = clean_shopping_df["Delivery_Charges"]

plt.figure(figsize=(10,8))

plt.scatter(x, y, facecolor="#7DCE82", edgecolor="black", s=100)
# Incorporate the other graph properties
plt.xlabel("Average Price", fontsize=13, fontstyle="italic")
plt.ylabel("Shipping Charges", fontsize=13, fontstyle="italic")
plt.title("Average Price vs Shipping Charges", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle="--", alpha=0.5)
# Save the figure
# plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()

# %%
# Build scatter plot for item cost vs shipping cost
x = clean_shopping_df["Transaction_Date"]
y = clean_shopping_df["Delivery_Charges"]

plt.figure(figsize=(10,8))

plt.scatter(x, y, facecolor="#7DCE82", edgecolor="black", s=100)
# Incorporate the other graph properties
plt.xlabel("Date", fontsize=13, fontstyle="italic")
plt.ylabel("Shipping Charges", fontsize=13, fontstyle="italic")
plt.title("Date vs Shipping Charges", fontweight="bold", fontsize=16)

plt.grid(color="lightgrey", linestyle="--", alpha=0.5)
# Save the figure
# plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()

# %%
# # Step 1: get the data
# x = "Avg_Price"
# y = "Delivery_Charges"

# # create the plot
# plt.figure(figsize=(10,6))
# sns.violinplot(data=x, color="firebrick")

# # customizations
# plt.xlabel("Average Price", fontstyle="italic", fontsize=12)
# plt.ylabel("Delivery", fontstyle="italic", fontsize=12)
# plt.title("Violinplot of Delivery and Average Price", fontsize=16, fontweight="bold")
# plt.ylim(0, 1000)

# plt.grid(color="lightgrey", axis="y", linestyle="--", alpha=0.25)

# # show
# plt.show()

# %%
# distribution
plt.figure(figsize=(20, 10))
sns.violinplot(data=clean_shopping_df, x="Gender", y="Delivery_Charges")
plt.title("Violin Plots of Gender and Delivery Charges")
plt.show()

# %%
# distribution
plt.figure(figsize=(20, 10))
sns.violinplot(data=clean_shopping_df, x="Gender", y="Avg_Price")
plt.title("Violin Plots of Gender and Delivery Charges")
plt.show()

# %%
# clean_shopping_df  = sns.clean_shopping_df('Shopping')
project_colors = ["#E8E288", "#00FFF5"]
sns.set_palette(project_colors) 
# class v / s fare barplot 
fig, ax = plt.subplots(figsize = ( 10, 5))
sns.barplot(ax=ax, x = 'Location', y = 'Delivery_Charges', hue = 'Gender', data = clean_shopping_df)
# # Set label for x-axis 
ax.set_xlabel( "Location" , size = 16) 
  
# Set label for y-axis 
ax.set_ylabel( "Delivery Charges" , size = 16) 
  
# Set title for plot 
ax.set_title( "Delivery Charges Based on Location and Gender" , size = 24 )  
# Show the plot
plt.show()

# %%
# Create a line plot using Seaborn
sns.lineplot(x='Transaction_Date', y='Delivery_Charges', data=clean_shopping_df)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Delivery Charge')
plt.title('Line Chart Example')

# Show the plot
plt.show()
# Out:
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(16, 10))
# Create the line plot with genders differentiated by color
sns.lineplot(x='Transaction_Date', y='Delivery_Charges', hue='Gender', data=clean_shopping_df, ci=None)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Delivery Charges')
plt.title('Chart Comparing the Delivery Charges Based on Dates, Charges, and Gender')

# Show the plot with a legend
plt.legend(title='Gender')
plt.show()
# Out:
# C:\Users\hobby\AppData\Local\Temp\ipykernel_14408\2719145855.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Transaction_Date', y='Delivery_Charges', hue='Gender', data=clean_shopping_df, ci=None)
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
project_colors = ["#E8E288", "#00FFF5"]
# Create the first line plot
sns.lineplot(x='Transaction_Date', y='Delivery_Charges', data=clean_shopping_df, label='M')

# Create the second line plot with the same data
sns.lineplot(x='Transaction_Date', y='Delivery_Charges', data=clean_shopping_df, label='F')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Delivery Charges')
plt.title('Line Chart with Two Lines')

# Show the plot with a legend
plt.legend()
plt.show()
# Out:
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\hobby\anaconda3\envs\dev\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## I would assume people would be more willing to spend more on shipping the higher cost the item. 
## It doesnt take into account the coupon codes and if they were used to get free shipping or not

# %%
project_colors = ["#FF8360","#7DCE82",]
sns.set_palette(project_colors)
fig, ax = plt.subplots(figsize = ( 10, 5))
sns.barplot(ax=ax, x = 'Location', y = 'Avg_Price', hue = 'Gender', data = clean_shopping_df)
ax.set_xlabel( "Location" , size = 16) 
  
# Set label for y-axis 
ax.set_ylabel( "Average Price" , size = 16) 
  
# Set title for plot 
ax.set_title( "Average Price Based on Location and Gender" , size = 24 ) 
# Show the plot
plt.show()

# %%
#creating subplots
ax=plt.subplots()
 
#plotting columns
ax=sns.barplot(x=clean_shopping_df["Location"],y=clean_shopping_df["Delivery_Charges"],color = 'lime')
ax=sns.barplot(x=clean_shopping_df["Location"],y=clean_shopping_df["Avg_Price"],color = 'green')
 
#renaming the axes
ax.set(xlabel="Location", ylabel="Price")
 
# visualizing illustration
plt.show()

# %%
ax = plt.subplots()
 
# plotting columns
ax = sns.barplot(x=clean_shopping_df["Location"], y=clean_shopping_df["Avg_Price"], color='lime')
ax = sns.barplot(x=clean_shopping_df["Location"], y=clean_shopping_df["Delivery_Charges"], color='green')
 
# renaming the axes
ax.set(xlabel="x-axis", ylabel="y-axis")
 
# visualizing illustration
plt.show()

# %%
# # Sample data (replace this with your actual data)
# clean_shopping = {
#     'Gender',
#     'Shipping Price'
#     'Average Cost'
# }

# clean_shopping_df = pd.DataFrame(clean_shopping)

# # Create a violin plot with split categories for gender
# plt.figure(figsize=(12, 6))
# sns.violinplot(x='Gender', y='Shipping Price', clean_shopping=clean_shopping_df, inner='quartile', palette='Set2')
# plt.title('Violin Plot of Shipping Price by Gender')
# plt.show()

# plt.figure(figsize=(12, 6))
# sns.violinplot(x='Shipping Charges', y='Average Cost', data=df, inner='quartile', palette='Set2')
# plt.title('Violin Plot of Average Cost by Gender')
# plt.show()

# %%
# count1 = clean_shopping_df["Delivery_Charges"].unique()
# print(count1)
unique_values = clean_shopping_df["Delivery_Charges"].unique()
unique_values_sorted = sorted(unique_values)
print(unique_values_sorted)
# Out:
# [0.0, 6.0, 6.46, 6.48, 6.5, 6.51, 8.36, 8.7, 8.91, 11.1, 12.0, 12.48, 12.76, 12.91, 12.99, 13.35, 13.38, 13.75, 13.78, 14.25, 14.41, 14.42, 14.85, 14.96, 15.27, 15.37, 15.72, 15.75, 16.1, 16.27, 16.47, 16.65, 16.85, 16.86, 17.08, 17.84, 17.96, 18.12, 18.16, 18.36, 18.47, 18.59, 18.65, 18.69, 18.96, 19.02, 19.05, 19.68, 19.94, 19.99, 20.0, 20.22, 20.33, 20.74, 20.78, 20.85, 20.91, 21.19, 21.29, 21.71, 21.92, 22.13, 22.29, 22.44, 22.58, 22.71, 23.01, 23.17, 23.62, 24.37, 24.47, 24.49, 24.56, 24.92, 25.27, 25.37, 25.44, 25.59, 25.73, 25.87, 26.2, 26.4, 26.43, 26.84, 26.86, 27.32, 27.62, 28.21, 28.37, 28.51, 28.69, 28.7, 28.73, 28.78, 28.82, 29.9, 29.95, 30.0, 30.35, 30.59, 30.92, 31.45, 32.08, 32.18, 33.04, 33.94, 34.16, 34.75, 34.94, 35.3, 35.32, 35.89, 35.96, 36.06, 37.01, 37.04, 37.19, 37.51, 37.83, 38.19, 39.27, 39.29, 39.46, 39.81, 39.86, 39.98, 40.25, 40.29, 40.74, 41.18, 41.22, 41.3, 42.28, 42.45, 42.67, 43.31, 44.06, 44.22, 44.4, 45.5, 45.72, 45.93, 46.5, 47.45, 47.56, 48.59, 49.5, 49.62, 49.73, 50.0, 50.74, 50.93, 51.81, 51.99, 52.17, 52.22, 52.38, 52.6, 53.68, 53.72, 53.78, 54.55, 55.73, 56.32, 57.33, 57.53, 57.74, 58.49, 58.93, 59.16, 60.67, 61.13, 61.62, 62.5, 62.71, 62.74, 63.91, 64.01, 67.28, 67.67, 68.82, 70.38, 70.67, 70.92, 71.99, 73.01, 73.23, 73.71, 73.92, 74.74, 75.0, 75.4, 75.54, 75.74, 77.22, 79.32, 80.38, 81.7, 82.48, 84.7, 84.78, 85.01, 85.33, 86.21, 86.74, 87.7, 87.89, 88.53, 91.58, 93.52, 97.35, 98.74, 99.55, 100.36, 101.26, 102.74, 102.79, 106.0, 106.38, 109.91, 110.74, 111.07, 115.38, 117.7, 120.0, 122.66, 122.74, 126.4, 126.76, 130.46, 132.02, 132.54, 134.74, 136.09, 139.57, 139.84, 140.68, 146.74, 155.84, 156.3, 158.74, 166.18, 170.78, 175.14, 176.35, 182.74, 190.42, 199.9, 210.44, 213.13, 213.31, 229.54, 245.74, 249.91, 250.01, 260.82, 294.0, 307.47, 323.47, 324.0, 344.78, 351.64, 354.0, 422.24, 492.84, 504.0, 521.36]

# %%
count = clean_shopping_df["Delivery_Charges"].nunique()
count
# Out:
# 267

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
counts_gender = clean_shopping_df.Gender.value_counts()
counts_gender.plot(kind='pie', autopct = '%1.1f%%')
plt.title('Percentage of Gender')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
counts_gender = clean_shopping_df.Gender.value_counts()
counts_gender.plot(kind='pie', autopct = '%1.1f%%')
plt.title('Percentage of Gender')
plt.show()

# %%
clean_shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52524 entries, 0 to 52923
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52524 non-null  int64
#  1   CustomerID           52524 non-null  float64
#  2   Gender               52524 non-null  object
#  3   Location             52524 non-null  object
#  4   Tenure_Months        52524 non-null  float64
#  5   Transaction_ID       52524 non-null  float64
#  6   Transaction_Date     52524 non-null  datetime64[ns]
#  7   Product_Description  52524 non-null  object
#  8   Product_Category     52524 non-null  object
#  9   Quantity             52524 non-null  float64
#  10  Avg_Price            52524 non-null  float64
#  11  Delivery_Charges     52524 non-null  float64
#  12  Coupon_Status        52524 non-null  object
#  13  GST                  52524 non-null  float64
#  14  Date                 52524 non-null  object
#  15  Offline_Spend        52524 non-null  float64
#  16  Online_Spend         52524 non-null  float64
#  17  Month                52524 non-null  int64
#  18  Coupon_Code          52524 non-null  object
#  19  Discount_pct         52524 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(2), object(7)
# memory usage: 8.4+ MB

# %%
# Step 1: Get the data
x = np.flip(summ1["Location"])
y = np.flip(summ1["Delivery_Charges"])
avg_num = summ1["Delivery_Charges"].mean()

# Step 2: Create the Canvas
plt.figure(figsize=(8,6))

# Step 3: Create the skeleton plot
plt.barh(x, y, color="firebrick")

# Step 4: Customization
plt.xlabel("Location", fontsize=12, fontstyle="italic")
plt.title("Delivery Charges and Location", fontsize=16, fontweight="bold")

plt.grid(axis="x", color="lightgrey", linestyle="--", alpha=0.5)
plt.vlines(avg_num, 0, 7, color="black", linestyle="--")
plt.text(9e6, 1, "Average Delivery Charges")

# Step 5: Show/Save
# plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Step 1: Get the data
# ----> 2 x = np.flip(summ1["Location"])
#       3 y = np.flip(summ1["Delivery_Charges"])
#       4 avg_num = summ1["Delivery_Charges"].mean()
#
# NameError: name 'summ1' is not defined

# %%
categories = clean_shopping_df[['Gender', 'Location', 'Delivery_Charges']]
values1 = clean_shopping_df["Location"]  # Values for the first set of bars
values2 = clean_shopping_df["Gender"]  # Values for the second set of bars
# Create the Bar Chart: Use Matplotlib to create the double bar chart.

x = np.arange(len(categories))  # the label locations

width = 0.35  # the width of the bars
fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, values1, width, label='Set 1')
bars2 = ax.bar(x + width/2, values2, width, label='Set 2')

ax.set_xlabel('Location')
ax.set_ylabel('Delivery_Charges')
ax.set_title('Double Bar Chart')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

plt.show()

# %%
categories = clean_shopping_df[['Gender', 'Location', 'Delivery_Charges']]
values1 = clean_shopping_df["Location"]
values2 = clean_shopping_df["Gender"]

x = np.arange(len(categories))
width = 0.35
fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, values1, width, label='Set 1')
bars2 = ax.bar(x + width/2, values2, width, label='Set 2')

ax.set_xlabel('Location')
ax.set_ylabel('Delivery Charges')
ax.set_title('Double Bar Chart')
ax.set_xticks(x)
ax.set_xticklabels(categories['Location'])  # Use the 'Location' column for x-tick labels
ax.legend()

plt.show()

# %%
# # Set x axis and tick locations
# x_axis = np.arange(len(clean_shopping_df))
# tick_locations = [value+0.4 for value in x_axis]
# # Create a list indicating where to write x labels and set figure size to adjust for space
# plt.figure(figsize=(20,4))
# plt.bar(x_axis, clean_shopping_df["Location", "Gender"], color='r', alpha=0.5, align="edge")
# plt.xticks(tick_locations, clean_shopping_df["Delivery_Charges"], rotation="vertical")
# plt.show()

# %%
# # Generate a pie plot showing the distribution of female versus male mice using Pandas
# counts_gender = clean_shopping_df.Gender()
# counts_gender.plot(kind='pie', autopct = '%1.1f%%')
# plt.title('Percentage of Each Gender')
# plt.show()

# %%
# labels = ["Gender"]

# # The values of each section of the pie chart
# # sizes = [220, 95, 80, 100]

# # The colors of each section of the pie chart
# colors = ["red", "orange"]

# # Tells matplotlib to separate the "Humans" section from the others
# explode = (0.1, 0, 0, 0)
# plt.pie(explode=explode, labels=labels, colors=colors,
#         autopct="%1.1f%%", shadow=True, startangle=140)
# plt.show()
