# %% [markdown]
# Question : Is there a difference between men and womens spending habits, ei: do men have fewer transactions but higher cost items vs women many small transactions with smaller transactions?

# %%
#importing libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
#loading the data
online_shopping_path = "../starter_code/online_shopping.csv"

# %%
#importing the .csv
shopping_data = pd.read_csv(online_shopping_path)

# %%
shopping_data.shape
# Out:
# (52955, 21)

# %%
#previewing the data
shopping_data.head()
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
# ...

# %%
# looking at the .info for null values and dtypes
shopping_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
# ...

# %%
# getting the column headings to use for analysis
print(shopping_data.columns)
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
#dropping the unnamed column
clean_shopping_df = shopping_data.drop('Unnamed: 0', axis=1, inplace=False)
clean_shopping_df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       2019-01-01
# 1     17850.0      M  Chicago           12.0         16680.0       2019-01-01
# 2     17850.0      M  Chicago           12.0         16696.0       2019-01-01
# 3     17850.0      M  Chicago           12.0         16699.0       2019-01-01
# 4     17850.0      M  Chicago           12.0         16700.0       2019-01-01
#
#       Product_SKU                                Product_Description  \
# 0  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2  GGOENEBQ078999             Nest Cam Outdoor Security Camera - USA
# 3  GGOENEBQ079099    Nest Protect Smoke + CO White Battery Alarm-USA
# 4  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
#
#   Product_Category  Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST  \
# ...

# %%
#dropping the product SKU column
clean_shop_df = clean_shopping_df.drop('Product_SKU', axis=1, inplace=False)
clean_shop_df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       2019-01-01
# 1     17850.0      M  Chicago           12.0         16680.0       2019-01-01
# 2     17850.0      M  Chicago           12.0         16696.0       2019-01-01
# 3     17850.0      M  Chicago           12.0         16699.0       2019-01-01
# 4     17850.0      M  Chicago           12.0         16700.0       2019-01-01
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
#
#    Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST      Date  \
# ...

# %%
clean_shop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52924 non-null  float64
#  1   Gender               52924 non-null  object
#  2   Location             52924 non-null  object
#  3   Tenure_Months        52924 non-null  float64
#  4   Transaction_ID       52924 non-null  float64
#  5   Transaction_Date     52924 non-null  object
#  6   Product_Description  52924 non-null  object
#  7   Product_Category     52955 non-null  object
#  8   Quantity             52924 non-null  float64
#  9   Avg_Price            52924 non-null  float64
#  10  Delivery_Charges     52924 non-null  float64
#  11  Coupon_Status        52924 non-null  object
#  12  GST                  52924 non-null  float64
#  13  Date                 52924 non-null  object
#  14  Offline_Spend        52924 non-null  float64
# ...

# %%
#dropping remaining null values
clean_df = clean_shop_df.dropna(how="any").reset_index(drop=True)
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52524 entries, 0 to 52523
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  object
#  6   Product_Description  52524 non-null  object
#  7   Product_Category     52524 non-null  object
#  8   Quantity             52524 non-null  float64
#  9   Avg_Price            52524 non-null  float64
#  10  Delivery_Charges     52524 non-null  float64
#  11  Coupon_Status        52524 non-null  object
#  12  GST                  52524 non-null  float64
#  13  Date                 52524 non-null  object
#  14  Offline_Spend        52524 non-null  float64
# ...

# %%
#looking at product counts
prod_category = clean_df.Product_Category.value_counts
prod_category()
# Out:
# Product_Category
# Apparel                 18126
# Nest-USA                14013
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Nest                     2198
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Nest-Canada               317
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64

# %%
#coupon status counts
coup_stat = clean_df.Coupon_Status.value_counts
coup_stat()
# Out:
# Coupon_Status
# Clicked     26720
# Used        17778
# Not Used     8026
# Name: count, dtype: int64

# %%
coup_code = clean_df.Coupon_Code.value_counts
coup_code()
# Out:
# Coupon_Code
# SALE20     6373
# SALE30     5915
# SALE10     5838
# ELEC10     4826
# ELEC30     4647
# ELEC20     4540
# EXTRA10    2317
# OFF10      2250
# EXTRA20    2211
# OFF20      2202
# OFF30      2061
# EXTRA30    2047
# NE30       1003
# NE20        740
# AIO10       654
# AIO20       618
# AIO30       610
# NE10        455
# NJ20        299
# NJ10        280
# HGEAR10     267
# HGEAR20     267
# HGEAR30     237
# WEMP20      205
# WEMP30      185
# NJ30        170
# WEMP10      164
# NCA10       116
# NCA30       110
# BT10         98
# ACC20        97
# NCA20        91
# GC10         89
# BT30         87
# BT20         83
# ACC30        77
# ACC10        60
# HOU20        50
# HOU10        42
# GC20         41
# HOU30        30
# GC30         29
# AND30        16
# AND10        14
# AND20        13
# Name: count, dtype: int64

# %%
#gender value counts
gender = clean_df.Gender.value_counts
gender()
# Out:
# Gender
# F    32767
# M    19757
# Name: count, dtype: int64

# %%
#location value counts
location = clean_df.Location.value_counts
location()
# Out:
# Location
# Chicago          18240
# California       16008
# New York         11097
# New Jersey        4470
# Washington DC     2709
# Name: count, dtype: int64

# %%
# convert date to month, day, year
clean_df["Transaction_Date"] = pd.to_datetime(clean_df["Transaction_Date"])
clean_df["Date"] = pd.to_datetime(clean_df["Date"])
#clean_df["Transaction_Date"] = clean_df["Transaction_Date"].dt.strftime("%m-%d-%Y")
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52524 entries, 0 to 52523
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           52524 non-null  float64
#  1   Gender               52524 non-null  object
#  2   Location             52524 non-null  object
#  3   Tenure_Months        52524 non-null  float64
#  4   Transaction_ID       52524 non-null  float64
#  5   Transaction_Date     52524 non-null  datetime64[ns]
#  6   Product_Description  52524 non-null  object
#  7   Product_Category     52524 non-null  object
#  8   Quantity             52524 non-null  float64
#  9   Avg_Price            52524 non-null  float64
#  10  Delivery_Charges     52524 non-null  float64
#  11  Coupon_Status        52524 non-null  object
#  12  GST                  52524 non-null  float64
#  13  Date                 52524 non-null  datetime64[ns]
# ...

# %%
clean_shopping_df.tail()
# Out:
#        CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 52950         NaN    NaN      NaN            NaN             NaN
# 52951         NaN    NaN      NaN            NaN             NaN
# 52952         NaN    NaN      NaN            NaN             NaN
# 52953         NaN    NaN      NaN            NaN             NaN
# 52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date Product_SKU Product_Description      Product_Category  \
# 52950              NaN         NaN                 NaN            Gift Cards
# 52951              NaN         NaN                 NaN  Notebooks & Journals
# 52952              NaN         NaN                 NaN               Android
# 52953              NaN         NaN                 NaN               Android
# 52954              NaN         NaN                 NaN               Android
#
#        Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST Date  \
# ...

# %%
#combining new york and new jersy into one group
clean_df["Location"] = clean_df.Location.replace({"New York": "New Jersey"})
clean_df.Location.value_counts()
# Out:
# Location
# Chicago          18240
# California       16008
# New Jersey       15567
# Washington DC     2709
# Name: count, dtype: int64

# %%
#combining washington DC and the new jersey group
clean_df["Location"] = clean_df.Location.replace({"New Jersey": "Washington DC"})
clean_df.Location.value_counts()
# Out:
# Location
# Washington DC    18276
# Chicago          18240
# California       16008
# Name: count, dtype: int64

# %%
#renaming the group to northeast
clean_df["Location"] = clean_df.Location.replace({"Washington DC": "North East"})
clean_df.Location.value_counts()
# Out:
# Location
# North East    18276
# Chicago       18240
# California    16008
# Name: count, dtype: int64

# %%
#combining nest canada and nest usa
clean_df["Product_Category"] = clean_df.Product_Category.replace({"Nest-Canada": "Nest-USA"})
clean_df.Product_Category.value_counts().head
# Out:
# <bound method NDFrame.head of Product_Category
# Apparel                 18126
# Nest-USA                14330
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Nest                     2198
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64>

# %%
#grouping all the nest categories together
clean_df["Product_Category"] = clean_df.Product_Category.replace({"Nest-USA": "Nest"})
clean_df.Product_Category.value_counts().head
# Out:
# <bound method NDFrame.head of Product_Category
# Apparel                 18126
# Nest                    16528
# Office                   6513
# Drinkware                3483
# Lifestyle                3092
# Bags                     1882
# Headgear                  771
# Notebooks & Journals      749
# Waze                      554
# Bottles                   268
# Accessories               234
# Gift Cards                159
# Housewares                122
# Android                    43
# Name: count, dtype: int64>

# %%
# set colors
project_colors = ["#FF8360","#E8E288","#7DCE82","#3CDBD3","#00FFF5"]
sns.set_palette(project_colors)

# %%
clean_df["Total_Amount"]=clean_df["Avg_Price"]*clean_df["Quantity"]+clean_df["Delivery_Charges"]
clean_df["Total_Transaction"]=clean_df["Offline_Spend"]+clean_df["Online_Spend"]
clean_df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       2019-01-01
# 1     17850.0      M  Chicago           12.0         16680.0       2019-01-01
# 2     17850.0      M  Chicago           12.0         16696.0       2019-01-01
# 3     17850.0      M  Chicago           12.0         16699.0       2019-01-01
# 4     17850.0      M  Chicago           12.0         16700.0       2019-01-01
#
#                                  Product_Description Product_Category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...             Nest
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...             Nest
# 2             Nest Cam Outdoor Security Camera - USA             Nest
# 3    Nest Protect Smoke + CO White Battery Alarm-USA             Nest
# 4  Nest Learning Thermostat 3rd Gen-USA - Stainle...             Nest
#
#    Quantity  Avg_Price  ...  Coupon_Status  GST       Date Offline_Spend  \
# ...

# %%
#Visualizing % of gender across dataset
gender = ["Male", "Female"]
#plugged in actual values of sum of male and female to get %
pie_gender = [19757,32767]
colors = ["#3CDBD3","#FF8360"]

explode = [0.1, 0.1]

#customize
plt.figure(figsize=(5, 5))
plt.pie(pie_gender, explode=explode, labels=gender, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("Overall Gender of Online Shoppers", fontweight="bold", fontsize=14)
plt.axis("equal")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Getting transaction spent by gender
#used groupby to gather information in "gender" column and then get_group to target M and F
tam = clean_df[["Total_Amount","Gender"]].groupby("Gender").get_group("M")["Total_Amount"].sum()
taf = clean_df[["Total_Amount","Gender"]].groupby("Gender").get_group("F")["Total_Amount"].sum()
colors = ["#FF8360", "#3CDBD3"]

plt.figure(figsize = (5, 5))

val = [tam,taf]

plt.pie(val,labels = ["Female","Male"], colors=colors, autopct="%1.1f%%", startangle=330, shadow=True, explode = (0.1,0.1),)
plt.axis("equal")
plt.title("Total Amount Spent by Gender", fontweight="bold", fontsize=14)
sns.set(style = "white")

# %%
#Creating double bar chart by gender and quantity
#used groupby to gather information from product category and gender columns
pg = clean_df.groupby(["Product_Category", "Gender"])["Product_Category"].count().unstack("Gender")

ax = pg[["F","M"]].plot(kind="bar")

plt.title("Gender-Based Analysis of Product Purchases", fontweight="bold", fontsize=14.5)

for container in ax.containers:
    ax.bar_label(container, size=10)

# %%
#Used head(6) to only show top 6 and used sort_values in decending order to make chart easier to read
pg = clean_df.groupby(["Product_Category", "Gender"])["Product_Category"].count().unstack("Gender")

ax = pg.sort_values(by="F", ascending=False)[["F","M"]].head(6).plot(kind="bar")

plt.title("Gender-Based Analysis of Product Purchases", fontweight="bold", fontsize=14.5)

for container in ax.containers:
    ax.bar_label(container, size=10)

# %%
pg.sort_values(by="F", ascending=False)
# Out:
# Gender                    F     M
# Product_Category
# Apparel               11355  6771
# Nest                  10165  6363
# Office                 4178  2335
# Drinkware              2181  1302
# Lifestyle              1908  1184
# Bags                   1182   700
# Headgear                504   267
# Notebooks & Journals    432   317
# Waze                    327   227
# Bottles                 174    94
# Accessories             143    91
# Gift Cards              119    40
# Housewares               73    49
# Android                  26    17

# %%
#created new df with "pop_sum" column to store population quantity by using sum to add values together
#the value created is not the actual value of the population but rather the value of the gender that each product is purchased by
#dont want actual numbers just want correct percentage for visual
df2 = clean_df[["Gender","Location", "Quantity"]]
df3 = df2.groupby(["Gender","Location"])["Quantity"].sum().reset_index(name="pop_sum")
df3
# Out:
#   Gender    Location  pop_sum
# 0      F  California  47310.0
# 1      F     Chicago  52490.0
# 2      F  North East  51156.0
# 3      M  California  24796.0
# 4      M     Chicago  30840.0
# 5      M  North East  29775.0

# %%
#created new df with decending order
df32 = df3.sort_values(by="Location", ascending=True)
df32
# Out:
#   Gender    Location  pop_sum
# 0      F  California  47310.0
# 3      M  California  24796.0
# 1      F     Chicago  52490.0
# 4      M     Chicago  30840.0
# 2      F  North East  51156.0
# 5      M  North East  29775.0

# %%
#created variable to store information to use for inner values of nested donut chart
#used to_list to add a list of values to variable assigned
in_val = df32["pop_sum"].to_list()

# %%
#Only want female values to show used mask and "not equal" to drop M
mask = df3["Gender"] != ("M")
dfg = df3.loc[mask].reset_index(drop=True)
dfg
# Out:
#   Gender    Location  pop_sum
# 0      F  California  47310.0
# 1      F     Chicago  52490.0
# 2      F  North East  51156.0

# %%
#did the same for males
mask = df3["Gender"] != ("F")
dfm = df3.loc[mask].reset_index(drop=True)
dfm
# Out:
#   Gender    Location  pop_sum
# 0      M  California  24796.0
# 1      M     Chicago  30840.0
# 2      M  North East  29775.0

# %%
#replaced both "M" and "F" with "H" to combine it together "H" represents "Human"
df3["Gender"] = df3["Gender"].replace({"M": "H", "F": "H"})
df3["Gender"].value_counts()
df3
# Out:
#   Gender    Location  pop_sum
# 0      H  California  47310.0
# 1      H     Chicago  52490.0
# 2      H  North East  51156.0
# 3      H  California  24796.0
# 4      H     Chicago  30840.0
# 5      H  North East  29775.0

# %%
#Used "H" to get sum vales of female and male in each location rather than just female and male values by each location
dft = df3.groupby(["Location"])["pop_sum"].sum().reset_index()
dft
# Out:
#      Location  pop_sum
# 0  California  72106.0
# 1     Chicago  83330.0
# 2  North East  80931.0

# %%
#created variable to store information to use for outer values of nested donut chart
#used to_list to add a list of values to variable assigned
out_val = dft["pop_sum"].to_list()

# %%
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

#used inner_val and outer_val
#used %1.1f%% to show outer circle % in order to determine which color represents which region
ax.pie(out_val, explode = [0, 0, 0], labels=["California", "Chicago", "North East"], autopct='%1.1f%%', startangle=330, radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(in_val, radius=1-size, startangle=330, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title="Female vs Male by Location")
plt.show()

# %%
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[60., 32.], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

#took out % vales and made title of chart bold
ax.pie(out_val, explode = [0, 0, 0], labels=["California", "Chicago", "North East"], startangle=330, radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(in_val, radius=1-size, startangle=330, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

plt.title("Female vs Male by Location", fontweight="bold", fontsize=12.5)
ax.set(aspect="equal")
plt.show()
